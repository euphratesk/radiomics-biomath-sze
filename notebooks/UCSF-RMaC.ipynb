# %%
import pandas as pd
import numpy as np
# Out:
# /home/euphrates/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/euphrates/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('phase_reg_key.csv')

# %%
pd.options.display.max_columns = 200

# %%
df.head()
# Out:
#           pid  noncon  arterial  delay  portven  mask  \
# 0  08FBroxzI6       2         0      1        1     2
# 1  0A87Rq5Hkl       2         1      0        0     2
# 2  0ByGP3oWJi       2         0      0        0     2
# 3  0HW0RoqB2y       2         1      0        1     2
# 4  0MPL7wuVkw       2         0      2        2     2
#
#                          ct_manufacturer  patient_age_years patient_sex  \
# 0      GE MEDICAL SYSTEMS LightSpeed VCT                 68           F
# 1  GE MEDICAL SYSTEMS Discovery CT750 HD                 90           F
# 2        GE MEDICAL SYSTEMS LightSpeed16                 48           M
# 3      GE MEDICAL SYSTEMS LightSpeed VCT                 39           M
# 4      GE MEDICAL SYSTEMS LightSpeed VCT                 61           M
#
#         pathology      tumor_type  pathology_grade tumor_laterality  \
# 0  angiomyolipoma  angiomyolipoma              NaN            right
# ...

# %%
df['pathology'].value_counts()
# Out:
# pathology
# clear cell                                                                           476
# oncocytoma                                                                           102
# papillary                                                                             91
# chromophobe                                                                           39
# angiomyolipoma                                                                        29
# renal cell carcinoma, NOS                                                             13
# clear cell, papillary                                                                  7
# simple cyst                                                                            6
# cystic                                                                                 5
# multilocular cystic                                                                    5
# ...

# %%
df['tumor_type'].value_counts()
# Out:
# tumor_type
# RCC               647
# oncocytoma        102
# other              42
# angiomyolipoma     30
# Name: count, dtype: int64

# %%
df[df['tumor_type'] =='angiomyolipoma']['pid'].values
# Out:
# <ArrowStringArray>
# ['08FBroxzI6', '1FeC2cgqyj', '1a7jTnjpn9', '34jxhEPOGB', '45Nh52EJwK',
#  '9Aue4ckfn8', 'AHXeVFmpFK', 'Cwg6Hv9E0n', 'Di7ARaJ8S6', 'IIFf4GZnYx',
#  'JMfIEEWlAz', 'NskoBo0acF', 'Q5hPqtDCir', 'STimK6AjK1', 'TUwzGuHPtD',
#  'VQwDzzw84L', 'WRfSZV3lw8', 'WooVhg7ysO', 'WxXHUmns4v', 'cwHnolRFQo',
#  'dkp1S2CrhL', 'flGZ1oVmQ3', 'fsbMU5j9mQ', 'gsresoXGbA', 'lyWL7zzWWi',
#  'nSIvfJZBlK', 'oo2Q4ig2bL', 'pXwitKy0oU', 'qhveYUigqX', 'tJYRUhVuhr']
# Length: 30, dtype: str

# %%
df[df['pathology'] =='angiomyolipoma']['pid'].count()
# Out:
# 29
