# %%
import numpy as np
import pandas as pd
import os
# Out:
# /home/euphrates/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/euphrates/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
for i in os.listdir():
    print({i},pd.read_csv(i).shape)
# Out:
# {'3.csv'} (25, 130)
# {'noncon-E2(portven-matched).csv'} (8, 130)
# {'0.csv'} (36, 130)
# {'4.csv'} (27, 130)
# {'5.csv'} (54, 130)
# {'noncon-E1.csv'} (9, 130)
# {'1.csv'} (3, 131)
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in os.listdir():
# ----> 2     print({i},pd.read_csv(i).shape)
#
# ...

# %%
len([i for i in pd.read_csv('0.csv').columns if i in pd.read_csv('noncon-E1.csv').columns])
# Out:
# 130

# %%
df1 = pd.read_csv('0.csv')

# %%
df2 = pd.read_csv('noncon-E1.csv')

# %%
pd.set_option("display.max_columns",140)

# %%
pd.set_option("display.max_rows",30)

# %%
df1.head()
# Out:
#   diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0          3.1.1.dev111+g8ed579383                      2.0.2
# 1          3.1.1.dev111+g8ed579383                      2.0.2
# 2          3.1.1.dev111+g8ed579383                      2.0.2
# 3          3.1.1.dev111+g8ed579383                      2.0.2
# 4          3.1.1.dev111+g8ed579383                      2.0.2
#
#   diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                          2.5.3                          1.8.0
# 1                          2.5.3                          1.8.0
# 2                          2.5.3                          1.8.0
# 3                          2.5.3                          1.8.0
# 4                          2.5.3                          1.8.0
#
#   diagnostics_Versions_Python  \
# 0                     3.12.13
# 1                     3.12.13
# 2                     3.12.13
# 3                     3.12.13
# 4                     3.12.13
#
# ...

# %%
df2.head()
# Out:
#   diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0          3.1.1.dev111+g8ed579383                      2.0.2
# 1          3.1.1.dev111+g8ed579383                      2.0.2
# 2          3.1.1.dev111+g8ed579383                      2.0.2
# 3          3.1.1.dev111+g8ed579383                      2.0.2
# 4          3.1.1.dev111+g8ed579383                      2.0.2
#
#   diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                          2.5.3                          1.8.0
# 1                          2.5.3                          1.8.0
# 2                          2.5.3                          1.8.0
# 3                          2.5.3                          1.8.0
# 4                          2.5.3                          1.8.0
#
#   diagnostics_Versions_Python  \
# 0                     3.12.13
# 1                     3.12.13
# 2                     3.12.13
# 3                     3.12.13
# 4                     3.12.13
#
# ...

# %%
[i for  i in pd.read_csv('1.csv').columns if i not in df1.columns]
# Out:
# ['Unnamed: 0']

# %%
pd.read_csv('1.csv').iloc[:,0]
# Out:
# 0    3.1.1.dev111+g8ed579383
# 1    3.1.1.dev111+g8ed579383
# 2    3.1.1.dev111+g8ed579383
# Name: diagnostics_Versions_PyRadiomics, dtype: str

# %%
pd.read_csv('2.csv')
# Out:
#    diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0           3.1.1.dev111+g8ed579383                      2.0.2
# 1           3.1.1.dev111+g8ed579383                      2.0.2
# 2           3.1.1.dev111+g8ed579383                      2.0.2
# 3           3.1.1.dev111+g8ed579383                      2.0.2
# 4           3.1.1.dev111+g8ed579383                      2.0.2
# 5           3.1.1.dev111+g8ed579383                      2.0.2
# 6           3.1.1.dev111+g8ed579383                      2.0.2
# 7           3.1.1.dev111+g8ed579383                      2.0.2
# 8           3.1.1.dev111+g8ed579383                      2.0.2
# 9           3.1.1.dev111+g8ed579383                      2.0.2
# 10          3.1.1.dev111+g8ed579383                      2.0.2
# 11          3.1.1.dev111+g8ed579383                      2.0.2
# 12          3.1.1.dev111+g8ed579383                      2.0.2
# 13          3.1.1.dev111+g8ed579383                      2.0.2
# ...

# %%
[i for  i in pd.read_csv('0.csv').columns if i not in pd.read_csv('CSV-noncon/noncon-E1.csv').columns]
# Out:
# []

# %%
ls = []

# %%
for i in os.listdir():
    if i.endswith(".csv"):
        ls.extend(pd.read_csv(i).iloc[:,-1])

# %%
ls
# Out:
# ['case_00071',
#  'case_00072',
#  'case_00073',
#  'case_00074',
#  'case_00075',
#  'case_00076',
#  'case_00077',
#  'case_00078',
#  'case_00079',
#  'case_00080',
#  'case_00081',
#  'case_00082',
#  'case_00083',
#  'case_00084',
#  'case_00085',
#  'case_00087',
#  'case_00088',
#  'case_00089',
#  'case_00090',
#  'case_00091',
#  'case_00126',
#  'case_00127',
#  'case_00129',
#  'case_00128',
#  'case_00130',
#  'case_00126',
#  'case_00127',
#  'case_00128',
#  'case_00129',
#  'case_00130',
#  'case_00131',
#  'case_00132',
#  'case_00133',
#  'case_00134',
#  'case_00135',
#  'case_00136',
#  'case_00138',
#  'case_00139',
#  'case_00140',
#  'case_00141',
#  'case_00142',
#  'case_00143',
#  'case_00144',
#  'case_00145',
#  'case_00146',
#  'case_00147',
#  'case_00148',
#  'case_00149',
#  'case_00150',
#  'case_00151',
#  'case_00152',
#  'case_00153',
#  'case_00154',
#  'case_00155',
#  'case_00156',
#  'case_00157',
#  'case_00158',
#  'case_00159',
# ...

# %%
case = ["case_00017","case_00043","case_00137","case_00176","case_00205","case_00469","case_00470","case_00484"]

# %%
[i for i in  case if i not in ls]
# Out:
# ['case_00017',
#  'case_00043',
#  'case_00137',
#  'case_00176',
#  'case_00205',
#  'case_00469',
#  'case_00470',
#  'case_00484']

# %%
df_p1 = pd.read_csv("portven-matched-1.csv")

# %%
df_p2 = pd.read_csv("portven-matched-2.csv")

# %%
df_aml1 = pd.read_csv("kidney-aml.csv")

# %%
df_0 = pd.read_csv("0.csv")

# %%
df_1 = pd.read_csv("1.csv")

# %%
df_2 = pd.read_csv("2.csv")

# %%
df_3 = pd.read_csv("3.csv")

# %%
df_4 = pd.read_csv("4.csv")

# %%
df_5 = pd.read_csv("5.csv")

# %%
df_6 = pd.read_csv("6.csv")

# %%
df = pd.concat([df_p1,df_p2,df_aml1,df_0,df_1,df_2,df_3,df_4,df_5,df_6], axis = 0, ignore_index= 1)

# %%
df.shape
# Out:
# (251, 130)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Columns: 130 entries, diagnostics_Versions_PyRadiomics to case_id
# dtypes: float64(110), int64(2), str(18)
# memory usage: 440.4 KB

# %%
df.head()
# Out:
#   diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0          3.1.1.dev111+g8ed579383                      2.0.2
# 1          3.1.1.dev111+g8ed579383                      2.0.2
# 2          3.1.1.dev111+g8ed579383                      2.0.2
# 3          3.1.1.dev111+g8ed579383                      2.0.2
# 4          3.1.1.dev111+g8ed579383                      2.0.2
#
#   diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                          2.5.3                          1.8.0
# 1                          2.5.3                          1.8.0
# 2                          2.5.3                          1.8.0
# 3                          2.5.3                          1.8.0
# 4                          2.5.3                          1.8.0
#
#   diagnostics_Versions_Python  \
# 0                     3.12.12
# 1                     3.12.12
# 2                     3.12.12
# 3                     3.12.12
# 4                     3.12.12
#
# ...

# %%
df_p1.shape
# Out:
# (3, 130)

# %%
df_p2.shape
# Out:
# (8, 130)

# %%
df_aml1.shape
# Out:
# (8, 130)

# %%
df
# Out:
#     diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0            3.1.1.dev111+g8ed579383                      2.0.2
# 1            3.1.1.dev111+g8ed579383                      2.0.2
# 2            3.1.1.dev111+g8ed579383                      2.0.2
# 3            3.1.1.dev111+g8ed579383                      2.0.2
# 4            3.1.1.dev111+g8ed579383                      2.0.2
# ..                               ...                        ...
# 246          3.1.1.dev111+g8ed579383                      2.0.2
# 247          3.1.1.dev111+g8ed579383                      2.0.2
# 248          3.1.1.dev111+g8ed579383                      2.0.2
# 249          3.1.1.dev111+g8ed579383                      2.0.2
# 250          3.1.1.dev111+g8ed579383                      2.0.2
#
#     diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                            2.5.3                          1.8.0
# ...

# %%
"case_2763".startswith("case")
# Out:
# True

# %%
[ "kits23" if i.startswith("case") else "ucsf-rmac-dataset" for i in df.case_id]
# Out:
# ['ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'ucsf-rmac-dataset',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
#  'kits23',
# ...

# %%
df["data_source"] = [ "kits23" if i.startswith("case") else "ucsf-rmac-dataset" for i in df.case_id]
# Out:
# /tmp/ipykernel_17702/3905411734.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["data_source"] = [ "kits23" if i.startswith("case") else "ucsf-rmac-dataset" for i in df.case_id]

# %%
pd.set_option.display.max_columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pd.set_option.display.max_columns
#
# AttributeError: 'function' object has no attribute 'display'

# %%
df.iloc[:,-2:]
# Out:
#              case_id        data_source
# 0    Cwg6Hv9E0n.hdf5  ucsf-rmac-dataset
# 1    1a7jTnjpn9.hdf5  ucsf-rmac-dataset
# 2    flGZ1oVmQ3.hdf5  ucsf-rmac-dataset
# 3    qhveYUigqX.hdf5  ucsf-rmac-dataset
# 4    nSIvfJZBlK.hdf5  ucsf-rmac-dataset
# ..               ...                ...
# 246       case_00204             kits23
# 247       case_00203             kits23
# 248       case_00202             kits23
# 249       case_00201             kits23
# 250       case_00200             kits23
#
# [251 rows x 2 columns]

# %%
ls =  [] 
index = []
for i in df_p1.select_dtypes(include=[np.number]):
    ls.append([df_p1[i].mean(),df_p2[i].mean(),df_aml1[i].mean()])
    index.append(i)
df_mean = pd.DataFrame(data=ls,columns = ["df_p1","df_p2","df_aml1"],index=index)

# %%
df_mean.to_dict()
# Out:
# {'df_p1': {'diagnostics_Image-original_Mean': -605.525496592276,
#   'diagnostics_Image-original_Minimum': -1692.6404398132836,
#   'diagnostics_Image-original_Maximum': 1329.205351447237,
#   'diagnostics_Mask-original_VoxelNum': 1517.3333333333333,
#   'diagnostics_Mask-original_VolumeNum': 1.0,
#   'original_shape_Elongation': 0.8643480805451694,
#   'original_shape_Flatness': 0.13917261862921523,
#   'original_shape_LeastAxisLength': 3.570838458533018,
#   'original_shape_MajorAxisLength': 26.09624135947803,
#   'original_shape_Maximum2DDiameterColumn': 21.67390962214756,
#   'original_shape_Maximum2DDiameterRow': 31.98401143530786,
#   'original_shape_Maximum2DDiameterSlice': 25.371918704054536,
#   'original_shape_Maximum3DDiameter': 32.06160100918313,
#   'original_shape_MeshVolume': 1493.7083333333333,
#   'original_shape_MinorAxisLength': 22.06276928856109,
#   'original_shape_Sphericity': 0.5004337768881867,
#   'original_shape_SurfaceArea': 1244.8963492613166,
# ...

# %%
df.select_dtypes(include=[np.number])

# %%
df_p1for i in df_p1.select_dtypes(include=[np.number]).columns

# %%
for i in df_p1.select_dtypes(include=[np.number]):
    print({i}, df_p1[i].mean())
# Out:
# {'diagnostics_Image-original_Mean'} -605.525496592276
# {'diagnostics_Image-original_Minimum'} -1692.6404398132836
# {'diagnostics_Image-original_Maximum'} 1329.205351447237
# {'diagnostics_Mask-original_VoxelNum'} 1517.3333333333333
# {'diagnostics_Mask-original_VolumeNum'} 1.0
# {'original_shape_Elongation'} 0.8643480805451694
# {'original_shape_Flatness'} 0.13917261862921523
# {'original_shape_LeastAxisLength'} 3.570838458533018
# {'original_shape_MajorAxisLength'} 26.09624135947803
# {'original_shape_Maximum2DDiameterColumn'} 21.67390962214756
# {'original_shape_Maximum2DDiameterRow'} 31.98401143530786
# {'original_shape_Maximum2DDiameterSlice'} 25.371918704054536
# {'original_shape_Maximum3DDiameter'} 32.06160100918313
# {'original_shape_MeshVolume'} 1493.7083333333333
# {'original_shape_MinorAxisLength'} 22.06276928856109
# {'original_shape_Sphericity'} 0.5004337768881867
# {'original_shape_SurfaceArea'} 1244.8963492613166
# ...

# %% [markdown]
# original_firstorder_Minimum
# original_firstorder_10Percentile

# %%
df.loc[:19,["original_firstorder_Minimum","original_firstorder_10Percentile"]]
# Out:
#     original_firstorder_Minimum  original_firstorder_10Percentile
# 0                   -113.047603                        -68.168552
# 1                      1.260124                         91.098124
# 2                    -60.835530                         50.612435
# 3                   -103.529007                         98.212590
# 4                   -113.146797                         66.898865
# 5                    -96.432169                         -5.453843
# 6                   -546.721313                        -75.582722
# 7                   -133.621735                        -53.755154
# 8                    -77.354538                         11.303544
# 9                    -79.962639                         72.553980
# 10                  -802.000000                       -126.000000
# 11                   -94.000000                          1.000000
# 12                   -96.000000                         45.000000
# ...

# %%
df.loc[:19,["original_firstorder_Minimum","original_firstorder_10Percentile"]].to_dict()
# Out:
# {'original_firstorder_Minimum': {0: -113.04760270974634,
#   1: 1.260124444961548,
#   2: -60.83552975845284,
#   3: -103.5290069580078,
#   4: -113.14679718017578,
#   5: -96.4321693239495,
#   6: -546.7213134765625,
#   7: -133.62173461914062,
#   8: -77.35453796386719,
#   9: -79.96263885498047,
#   10: -802.0,
#   11: -94.0,
#   12: -96.0,
#   13: -101.0,
#   14: -112.0,
#   15: -86.0,
#   16: -93.0,
#   17: -95.0,
#   18: -111.0,
#   19: -104.0},
#  'original_firstorder_10Percentile': {0: -68.16855232195488,
#   1: 91.09812393188476,
#   2: 50.61243515113016,
#   3: 98.21259002685548,
#   4: 66.89886474609375,
#   5: -5.453843023605804,
#   6: -75.58272247314453,
#   7: -53.75515441894531,
#   8: 11.303544235229491,
#   9: 72.55398025512697,
#   10: -126.0,
#   11: 1.0,
#   12: 45.0,
#   13: 31.0,
#   14: 21.0,
#   15: 15.0,
#   16: 50.0,
#   17: -2.0,
#   18: 25.0,
#   19: 8.0}}

# %%
df.columns.to_list()
# Out:
# ['diagnostics_Versions_PyRadiomics',
#  'diagnostics_Versions_Numpy',
#  'diagnostics_Versions_SimpleITK',
#  'diagnostics_Versions_PyWavelet',
#  'diagnostics_Versions_Python',
#  'diagnostics_Configuration_Settings',
#  'diagnostics_Configuration_EnabledImageTypes',
#  'diagnostics_Image-original_Hash',
#  'diagnostics_Image-original_Dimensionality',
#  'diagnostics_Image-original_Spacing',
#  'diagnostics_Image-original_Size',
#  'diagnostics_Image-original_Mean',
#  'diagnostics_Image-original_Minimum',
#  'diagnostics_Image-original_Maximum',
#  'diagnostics_Mask-original_Hash',
#  'diagnostics_Mask-original_Spacing',
#  'diagnostics_Mask-original_Size',
#  'diagnostics_Mask-original_BoundingBox',
#  'diagnostics_Mask-original_VoxelNum',
#  'diagnostics_Mask-original_VolumeNum',
#  'diagnostics_Mask-original_CenterOfMassIndex',
#  'diagnostics_Mask-original_CenterOfMass',
#  'original_shape_Elongation',
#  'original_shape_Flatness',
#  'original_shape_LeastAxisLength',
# ...

# %%
df_ucsf = pd.read_csv("phase_reg_key.csv")

# %%
df_kits23 = pd.read_json("kits23.json")

# %%
df_ucsf
# Out:
#             pid  noncon  arterial  delay  portven  mask  \
# 0    08FBroxzI6       2         0      1        1     2
# 1    0A87Rq5Hkl       2         1      0        0     2
# 2    0ByGP3oWJi       2         0      0        0     2
# 3    0HW0RoqB2y       2         1      0        1     2
# 4    0MPL7wuVkw       2         0      2        2     2
# ..          ...     ...       ...    ...      ...   ...
# 826  zmwtNTDvF2       2         2      0        2     2
# 827  zrDL8HfWpB       2         0      2        2     2
# 828  zrvxpvxpGd       2         2      2        2     2
# 829  zs9u4LLGez       2         1      1        0     2
# 830  zsg5AUbKwd       2         0      1        1     2
#
#                            ct_manufacturer  patient_age_years patient_sex  \
# 0        GE MEDICAL SYSTEMS LightSpeed VCT                 68           F
# 1    GE MEDICAL SYSTEMS Discovery CT750 HD                 90           F
# ...

# %%
pd.set_option("display.max_rows", 100)

# %%
df_ucsf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pid                831 non-null    str
#  1   noncon             831 non-null    int64
#  2   arterial           831 non-null    int64
#  3   delay              831 non-null    int64
#  4   portven            831 non-null    int64
#  5   mask               831 non-null    int64
#  6   ct_manufacturer    831 non-null    str
#  7   patient_age_years  831 non-null    int64
#  8   patient_sex        831 non-null    str
#  9   pathology          821 non-null    str
#  10  tumor_type         821 non-null    str
#  11  pathology_grade    648 non-null    float64
#  12  tumor_laterality   821 non-null    str
#  13  tumor_size_cm      821 non-null    float64
#  14  tumor_biopsy_type  819 non-null    str
# dtypes: float64(2), int64(6), str(7)
# memory usage: 161.0 KB

# %%
df_ucsf.columns
# Out:
# Index(['pid', 'noncon', 'arterial', 'delay', 'portven', 'mask',
#        'ct_manufacturer', 'patient_age_years', 'patient_sex', 'pathology',
#        'tumor_type', 'pathology_grade', 'tumor_laterality', 'tumor_size_cm',
#        'tumor_biopsy_type'],
#       dtype='str')

# %%
df_kits23.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   case_id                         489 non-null    str
#  1   gender                          489 non-null    str
#  2   vital_status                    489 non-null    str
#  3   vital_days_after_surgery        489 non-null    int64
#  4   bmi                             488 non-null    float64
#  5   comorbidities                   489 non-null    object
#  6   age_at_nephrectomy              489 non-null    int64
#  7   hospitalization                 489 non-null    int64
#  8   er_visit                        487 non-null    float64
#  9   readmission                     487 non-null    float64
#  10  surgery_type                    489 non-null    str
#  11  surgical_approach               488 non-null    str
# ...

# %%
df_kits23.columns
# Out:
# Index(['case_id', 'gender', 'vital_status', 'vital_days_after_surgery', 'bmi',
#        'comorbidities', 'age_at_nephrectomy', 'hospitalization', 'er_visit',
#        'readmission', 'surgery_type', 'surgical_approach',
#        'surgical_procedure', 'estimated_blood_loss',
#        'clavien_surgical_complications', 'intraoperative_complications',
#        'ischemia_time', 'operative_time', 'smoking_history',
#        'age_when_quit_smoking', 'pack_years', 'chewing_tobacco_use',
#        'alcohol_use', 'radiographic_size', 'cytoreductive', 'pathologic_size',
#        'malignant', 'pathology_t_stage', 'pathology_n_stage',
#        'pathology_m_stage', 'tumor_histologic_subtype', 'tumor_necrosis',
#        'tumor_isup_grade', 'positive_resection_margins',
#        'sarcomatoid_features', 'rhabdoid_features', 'last_preop_egfr',
#        'first_postop_egfr', 'last_postop_egfr', 'aua_risk_score'],
#       dtype='str')

# %%
df_ucsf["pathology"].value_counts()
# Out:
# pathology
# clear cell                                                                           476
# oncocytoma                                                                           102
# papillary                                                                             91
# chromophobe                                                                           39
# angiomyolipoma                                                                        29
# renal cell carcinoma, NOS                                                             13
# clear cell, papillary                                                                  7
# simple cyst                                                                            6
# cystic                                                                                 5
# multilocular cystic                                                                    5
# ...

# %%
df_ucsf["tumor_type"].value_counts()
# Out:
# tumor_type
# RCC               647
# oncocytoma        102
# other              42
# angiomyolipoma     30
# Name: count, dtype: int64

# %%
df_ucsf[(df_ucsf["pathology"]!="angiomyolipoma") & (df_ucsf["tumor_type"]=="angiomyolipoma")]
# Out:
#             pid  noncon  arterial  delay  portven  mask  \
# 534  dkp1S2CrhL       2         0      1        1     2
#
#                      ct_manufacturer  patient_age_years patient_sex  \
# 534  GE MEDICAL SYSTEMS LightSpeed16                 29           F
#
#                  pathology      tumor_type  pathology_grade tumor_laterality  \
# 534  cystic angiomyolipoma  angiomyolipoma              NaN             left
#
#      tumor_size_cm    tumor_biopsy_type
# 534            2.0  partial nephrectomy

# %%
df[ucsf[df_ucsf["tumor_type"]=="angiomyolipoma"].shape
# Out:
# /tmp/ipykernel_17702/586731379.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_ucsf["tumor_type"]=="angiomyolipoma"].shape
# (11, 131)
