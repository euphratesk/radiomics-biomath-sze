# %%
import pandas as pd
import numpy as np
import os

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import log_loss, recall_score, accuracy_score, precision_score, f1_score,classification_report,confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, auc

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.getcwd()
# Out:
# '/home/euphrates/Desktop/dreps/DS/Radiomics/Boun-radiomics/notebooks/ozyegin'

# %%
os.listdir("CSV")
# Out:
# ['rcc2.csv',
#  'rcc1.csv',
#  'test2.csv',
#  'originalitself.csv',
#  'flippedOriginal.csv',
#  'phase_reg_key.csv',
#  'test1.csv',
#  'dilatedResized.csv',
#  'erodedOriginal.csv',
#  'dilatedOriginal.csv',
#  'resizeditself.csv',
#  'erodedResized.csv',
#  'flippedResized.csv']

# %% [markdown]
# ###  UCSF  --arterial  -- aml

# %%
reg = pd.read_csv('CSV/phase_reg_key.csv')

# %%
reg.columns
# Out:
# Index(['pid', 'noncon', 'arterial', 'delay', 'portven', 'mask',
#        'ct_manufacturer', 'patient_age_years', 'patient_sex', 'pathology',
#        'tumor_type', 'pathology_grade', 'tumor_laterality', 'tumor_size_cm',
#        'tumor_biopsy_type'],
#       dtype='object')

# %%
reg[(reg['tumor_type'].isin(['angiomyolipoma']))or(reg['pathology'].isin(['angiomyolipoma']))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13746/3335850022.py in ?()
# ----> 1 reg[(reg['tumor_type'].isin(['angiomyolipoma']))or(reg['pathology'].isin(['angiomyolipoma']))]
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
reg[reg['tumor_type'].isin(['angiomyolipoma'])][["pid",'tumor_type','pathology']]
# Out:
#             pid      tumor_type              pathology
# 0    08FBroxzI6  angiomyolipoma         angiomyolipoma
# 16   1FeC2cgqyj  angiomyolipoma         angiomyolipoma
# 21   1a7jTnjpn9  angiomyolipoma         angiomyolipoma
# 35   34jxhEPOGB  angiomyolipoma         angiomyolipoma
# 45   45Nh52EJwK  angiomyolipoma         angiomyolipoma
# 108  9Aue4ckfn8  angiomyolipoma         angiomyolipoma
# 123  AHXeVFmpFK  angiomyolipoma         angiomyolipoma
# 167  Cwg6Hv9E0n  angiomyolipoma         angiomyolipoma
# 178  Di7ARaJ8S6  angiomyolipoma         angiomyolipoma
# 239  IIFf4GZnYx  angiomyolipoma         angiomyolipoma
# 248  JMfIEEWlAz  angiomyolipoma         angiomyolipoma
# 321  NskoBo0acF  angiomyolipoma         angiomyolipoma
# 346  Q5hPqtDCir  angiomyolipoma         angiomyolipoma
# 386  STimK6AjK1  angiomyolipoma         angiomyolipoma
# 396  TUwzGuHPtD  angiomyolipoma         angiomyolipoma
# 427  VQwDzzw84L  angiomyolipoma         angiomyolipoma
# 443  WRfSZV3lw8  angiomyolipoma         angiomyolipoma
# 449  WooVhg7ysO  angiomyolipoma         angiomyolipoma
# 450  WxXHUmns4v  angiomyolipoma         angiomyolipoma
# 517  cwHnolRFQo  angiomyolipoma         angiomyolipoma
# 534  dkp1S2CrhL  angiomyolipoma  cystic angiomyolipoma
# 555  flGZ1oVmQ3  angiomyolipoma         angiomyolipoma
# 558  fsbMU5j9mQ  angiomyolipoma         angiomyolipoma
# 577  gsresoXGbA  angiomyolipoma         angiomyolipoma
# 638  lyWL7zzWWi  angiomyolipoma         angiomyolipoma
# 659  nSIvfJZBlK  angiomyolipoma         angiomyolipoma
# 678  oo2Q4ig2bL  angiomyolipoma         angiomyolipoma
# 685  pXwitKy0oU  angiomyolipoma         angiomyolipoma
# 703  qhveYUigqX  angiomyolipoma         angiomyolipoma
# 732  tJYRUhVuhr  angiomyolipoma         angiomyolipoma

# %%
reg[reg['tumor_type'].isin(['angiomyolipoma'])][["pid",'tumor_type','pathology']].shape
# Out:
# (30, 3)

# %%
os.listdir("/media/euphrates/DS-Backup/angiomyolipoma/ucsf-rmac-dataset")
# Out:
# ['1a7jTnjpn9.hdf5',
#  'oo2Q4ig2bL.hdf5',
#  '1FeC2cgqyj.hdf5',
#  'AHXeVFmpFK.hdf5',
#  'Cwg6Hv9E0n.hdf5',
#  'cwHnolRFQo.hdf5',
#  'Di7ARaJ8S6.hdf5',
#  'dkp1S2CrhL.hdf5',
#  'flGZ1oVmQ3.hdf5',
#  'fsbMU5j9mQ.hdf5',
#  'gsresoXGbA.hdf5',
#  'IIFf4GZnYx.hdf5',
#  'JMfIEEWlAz.hdf5',
#  'lyWL7zzWWi.hdf5',
#  'pXwitKy0oU.hdf5',
#  'STimK6AjK1.hdf5',
#  'tJYRUhVuhr.hdf5',
#  'TUwzGuHPtD.hdf5',
#  'VQwDzzw84L.hdf5',
#  'WooVhg7ysO.hdf5',
#  'WRfSZV3lw8.hdf5',
#  'WxXHUmns4v.hdf5',
#  '08FBroxzI6.hdf5',
#  '9Aue4ckfn8.hdf5',
#  '34jxhEPOGB.hdf5',
#  '45Nh52EJwK.hdf5',
#  'nSIvfJZBlK.hdf5',
#  'NskoBo0acF.hdf5',
#  'Q5hPqtDCir.hdf5',
#  'qhveYUigqX.hdf5']

# %%
[i for i in reg[reg['pathology'].isin(['angiomyolipoma'])].pid if i not in [i.split('.')[0] for i in os.listdir("/media/euphrates/DS-Backup/angiomyolipoma/ucsf-rmac-dataset")]]
# Out:
# []

# %%
[i.split('.')[0] for i in os.listdir("/media/euphrates/DS-Backup/angiomyolipoma/ucsf-rmac-dataset")]
# Out:
# ['1a7jTnjpn9',
#  'oo2Q4ig2bL',
#  '1FeC2cgqyj',
#  'AHXeVFmpFK',
#  'Cwg6Hv9E0n',
#  'cwHnolRFQo',
#  'Di7ARaJ8S6',
#  'dkp1S2CrhL',
#  'flGZ1oVmQ3',
#  'fsbMU5j9mQ',
#  'gsresoXGbA',
#  'IIFf4GZnYx',
#  'JMfIEEWlAz',
#  'lyWL7zzWWi',
#  'pXwitKy0oU',
#  'STimK6AjK1',
#  'tJYRUhVuhr',
#  'TUwzGuHPtD',
#  'VQwDzzw84L',
#  'WooVhg7ysO',
#  'WRfSZV3lw8',
#  'WxXHUmns4v',
#  '08FBroxzI6',
#  '9Aue4ckfn8',
#  '34jxhEPOGB',
#  '45Nh52EJwK',
#  'nSIvfJZBlK',
#  'NskoBo0acF',
#  'Q5hPqtDCir',
#  'qhveYUigqX']

# %%
'dkp1S2CrhL' in [i.split('.')[0] for i in os.listdir("/media/euphrates/DS-Backup/angiomyolipoma/ucsf-rmac-dataset")]
# Out:
# True

# %%
dd1= pd.read_csv('CSV/dilatedOriginal.csv')

# %%
dd1.shape
# Out:
# (8, 1180)

# %%
dd1['augmentation'] = 'dilated'
dd1['source_subset'] = 'Original'

# %%
dd2= pd.read_csv('CSV/dilatedResized.csv')

# %%
dd2.shape
# Out:
# (3, 1180)

# %%
dd2['augmentation'] = 'dilated'
dd2['source_subset'] = 'Resized'

# %%
df1= pd.read_csv('CSV/flippedOriginal.csv')

# %%
df1.shape
# Out:
# (8, 1180)

# %%
df1['augmentation'] = 'flipped'
df1['source_subset'] = 'Original'

# %%
df2 = pd.read_csv('CSV/flippedResized.csv')

# %%
df2.shape
# Out:
# (3, 1180)

# %%
df2['augmentation'] = 'flipped'
df2['source_subset'] = 'Resized'

# %%
de1 = pd.read_csv('CSV/erodedOriginal.csv')

# %%
de1.shape
# Out:
# (8, 1180)

# %%
de1['augmentation'] = 'eroded'
de1['source_subset'] = 'Original'

# %%
de2 = pd.read_csv('CSV/erodedResized.csv')

# %%
de2.shape
# Out:
# (3, 1180)

# %%
de2['augmentation'] = 'eroded'
de2['source_subset'] = 'Resized'

# %%
do = pd.read_csv('CSV/originalitself.csv')

# %%
do.shape
# Out:
# (8, 1180)

# %%
do['augmentation'] = 'NOT'
do['source_subset'] = 'Original'

# %%
dr = pd.read_csv('CSV/resizeditself.csv')

# %%
dr.shape
# Out:
# (3, 1180)

# %%
dr['augmentation'] = 'NOT'
dr['source_subset'] = 'Resized'

# %%
drcc1 = pd.read_csv('CSV/rcc1.csv')
drcc1.shape
# Out:
# (23, 1180)

# %%
drcc1['augmentation'] = 'NOT'
drcc1['source_subset'] = 'Original-RCC'

# %%
drcc2 = pd.read_csv('CSV/rcc2.csv')

# %%
drcc2.shape
# Out:
# (35, 1180)

# %%
drcc2['augmentation'] = 'NOT'
drcc2['source_subset'] = 'Original-RCC'

# %%
dfA= pd.concat([dd1,dd2,df1,df2,de1,de2,do,dr], axis = 0, ignore_index= 1)

# %%
dfA.shape
# Out:
# (44, 1182)

# %%
dfA['target'] = 1

# %%
dfR = pd.concat([drcc1,drcc2], axis = 0, ignore_index= 1)

# %%
dfR.shape
# Out:
# (58, 1182)

# %%
dfR['target'] = 0

# %%
dfU = pd.concat([dfA,dfR], axis = 0, ignore_index= 1)

# %%
dfU.drop('pathology_grade', axis =1, inplace= True)

# %%
dfU['case_id'] = dfU.PID

# %%
y = dfU['target']

# %%
df_backup = dfU[['case_id','augmentation','source_subset','target']]

# %%
df_backup.sample(10)
# Out:
#        case_id augmentation source_subset  target
# 35  STimK6AjK1          NOT      Original       1
# 46  6S3AR8Qv8n          NOT  Original-RCC       0
# 79  RzuLk6CZhm          NOT  Original-RCC       0
# 71  B3uXUCxmk3          NOT  Original-RCC       0
# 45  5CZeU5xT7S          NOT  Original-RCC       0
# 57  OoWZhrPYs5          NOT  Original-RCC       0
# 69  5VcthT0eZp          NOT  Original-RCC       0
# 68  5OjuFGw7YB          NOT  Original-RCC       0
# 64  fFUuqn2Cdh          NOT  Original-RCC       0
# 51  DcvE7Qbk7u          NOT  Original-RCC       0

# %%
dfU.isnull().sum()
# Out:
# PID                                      0
# label                                    0
# tumor_type                               0
# pathology                                0
# Patient_Age                              0
#                                         ..
# diagnostics_Mask-interpolated_Maximum    0
# augmentation                             0
# source_subset                            0
# target                                   0
# case_id                                  0
# Length: 1183, dtype: int64

# %%
dfU.select_dtypes(include='object').groupby('Manufacturer')['Manufacturer'].count()
# Out:
# Manufacturer
# GE MEDICAL SYSTEMS BrightSpeed            1
# GE MEDICAL SYSTEMS Discovery CT750 HD    10
# GE MEDICAL SYSTEMS Discovery STE          1
# GE MEDICAL SYSTEMS GENESIS_ZEUS           1
# GE MEDICAL SYSTEMS HiSpeed CT/i           4
# GE MEDICAL SYSTEMS LightSpeed Pro 16      1
# GE MEDICAL SYSTEMS LightSpeed QX/i        1
# GE MEDICAL SYSTEMS LightSpeed Ultra       4
# GE MEDICAL SYSTEMS LightSpeed VCT        23
# GE MEDICAL SYSTEMS LightSpeed16           8
# GE MEDICAL SYSTEMS Optima CT660           7
# GE MEDICAL SYSTEMS Revolution CT          1
# Philips Brilliance 64                     2
# Philips Ingenuity CT                      1
# Philips Mx8000 IDT                        1
# Philips Mx8000 IDT 16                     7
# SIEMENS Biograph 64                       1
# SIEMENS SOMATOM Definition AS             2
# SIEMENS SOMATOM Definition AS+            3
# SIEMENS SOMATOM Definition Flash          1
# SIEMENS Sensation 16                      2
# SIEMENS Sensation 40                      4
# SIEMENS Sensation 64                      2
# TOSHIBA Aquilion                         14
# Name: Manufacturer, dtype: int64

# %%
dfU.groupby('Manufacturer')[dfU.select_dtypes(exclude='object').columns].mean().sum().plot.line()
plt.xticks(rotation = 45)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.]),
#  [Text(-200.0, 0, 'wavelet-HHH_firstorder_10Percentile'),
#   Text(0.0, 0, 'tumor_type'),
#   Text(200.0, 0, 'log-sigma-1-0-mm-3D_ngtdm_Contrast'),
#   Text(400.0, 0, 'wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation'),
#   Text(600.0, 0, 'wavelet-LHH_glcm_DifferenceVariance'),
#   Text(800.0, 0, 'wavelet-HLH_glcm_SumEntropy'),
#   Text(1000.0, 0, 'wavelet-HHH_glrlm_RunVariance'),
#   Text(1200.0, 0, ''),
#   Text(1400.0, 0, '')])

# %%
from sklearn.decomposition import PCA

# %%
dfU.select_dtypes(exclude = "object").shape
# Out:
# (102, 1146)

# %%
dfU.drop(columns=['case_id','augmentation','source_subset','target'],axis=1).select_dtypes(exclude = "object").shape
# Out:
# (102, 1145)

# %%
df_pca = dfU.drop(['case_id','augmentation','source_subset','target'],axis=1).select_dtypes(exclude = "object")

# %%
sc = StandardScaler()

# %%
scaled_df_pca = sc.fit_transform(df_pca)

# %%
pc = PCA().fit(scaled_df_pca)

# %%
len(pc.explained_variance_ratio_)
# Out:
# 102

# %%
x = range(1,103)
plt.plot(x, np.cumsum(pc.explained_variance_ratio_),)
plt.xlabel("Component count")
plt.ylabel("Variance Ratio")
# Out:
# Text(0, 0.5, 'Variance Ratio')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your original setup
x = range(1, 103)
cum_sum = np.cumsum(pc.explained_variance_ratio_)

# Create the base plot
plt.plot(x, cum_sum, color='blue', label='Cumulative Variance')
plt.xlabel("Component count")
plt.ylabel("Variance Ratio")

# Keep a set of coordinates to avoid duplicate labels if thresholds and components overlap
processed_points = set()

# --- 1. Process specific component counts ---
target_components = [0, 1, 10]

for c in target_components:
    if c == 0:
        comp_count, actual_val = 0, 0.0
    elif c in x:
        idx = list(x).index(c)
        comp_count, actual_val = c, cum_sum[idx]
    else:
        continue
    processed_points.add((comp_count, actual_val))

# --- 2. Process threshold variables from the former code ---
thresholds = [0.80, 0.90, 0.95]

for t in thresholds:
    under_threshold_indices = np.where(cum_sum >= t)[0]
    if len(under_threshold_indices) > 0:
        idx = under_threshold_indices[0]
        comp_count, actual_val = x[idx], cum_sum[idx]
        processed_points.add((comp_count, actual_val))

# --- 3. Plot and Annotate all unique critical points ---
for comp_count, actual_val in sorted(processed_points):
    # Plot a red dot on the critical point
    plt.scatter(comp_count, actual_val, color='red', s=40, zorder=5)
    
    # Draw dashed guide lines to the axes
    plt.axvline(x=comp_count, color='gray', linestyle='--', alpha=0.4)
    plt.axhline(y=actual_val, color='gray', linestyle='--', alpha=0.4)
    
    # Dynamic text positioning: if it's near (0,0), push text up. Otherwise, push it down.
    y_offset = 0.02 if actual_val < 0.1 else -0.03
    
    # Display the exact axis numbers next to the point
    plt.text(comp_count + 1.5, actual_val + y_offset, f"({comp_count}, {actual_val:.2f})", 
             fontsize=9, color='red', weight='bold')

plt.title("PCA Cumulative Explained Variance (Fixed Components & Thresholds)")
plt.grid(True, linestyle=':', alpha=0.6)

# Provide some breathing room on the canvas edges for the labels
plt.xlim(-3, 105)
plt.ylim(-0.05, 1.05)

plt.tight_layout()

# Save or display the plot
plt.savefig("explained_variance_plot.png")

# %%
scaled_df_pca.shape
# Out:
# (102, 1145)

# %%
pca = PCA(n_components=26)

# %%
scaled_df_pca.shape
# Out:
# (102, 1145)

# %%
p_scaled = pca.fit_transform(scaled_df_pca)

# %%
p_scaled
# Out:
# array([[-15.38993669,   5.08690068,   7.37854082, ...,  -0.22138277,
#           0.41938922,  -0.81723917],
#        [ -6.14391899,  -1.1120223 ,   8.2147891 , ...,  -0.66302446,
#          -0.18742644,   0.92473404],
#        [ -3.0973338 ,  -5.55876842,  20.10386787, ...,  -3.76379119,
#           0.13168364,   0.94065043],
#        ...,
#        [ -0.84850156,   2.61999513,  -9.70237051, ...,  -3.0783901 ,
#           0.7951982 ,   1.97578737],
#        [-19.41382967,   0.24047661,  20.33512086, ...,  -4.62998272,
#          -1.42392708,  -4.69774469],
#        [ 10.09024639,  -2.88428644,  -6.8743832 , ...,  -0.41580006,
#          -1.57595481,  -3.16006844]])

# %%
X = p_scaled

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.1, random_state= 43 )

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 0, 0, 0, 0, 1, 0, 0, 1])

# %%
y_test
# Out:
# 20    1
# 2     1
# 15    1
# 22    1
# 57    0
# 93    0
# 69    0
# 55    0
# 11    1
# 80    0
# 9     1
# Name: target, dtype: int64

# %%
eval_metric(svc, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[4 1]
#  [2 4]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.80      0.67      0.73         6
#
#     accuracy                           0.73        11
#    macro avg       0.73      0.73      0.73        11
# weighted avg       0.74      0.73      0.73        11
#
#
# Train_Set
# [[53  0]
#  [ 5 33]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        53
#            1       1.00      0.87      0.93        38
#
#     accuracy                           0.95        91
#    macro avg       0.96      0.93      0.94        91
# weighted avg       0.95      0.95      0.94        91

# %%
from sklearn.metrics import RocCurveDisplay,PrecisionRecallDisplay,ConfusionMatrixDisplay

# %%
RocCurveDisplay.from_estimator(svc,X_test,y_test)
plt.show()

# %%
PrecisionRecallDisplay.from_estimator(svc,X_test,y_test)
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(svc,X_test,y_test)
plt.show()

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier
xg = XGBClassifier()

# %%
xg.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xg.predict(X_test)

# %%
eval_metric(xg,X_train,y_train,X_test,y_test)
# Out:
# Test_Set
# [[4 1]
#  [3 3]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.75      0.50      0.60         6
#
#     accuracy                           0.64        11
#    macro avg       0.66      0.65      0.63        11
# weighted avg       0.67      0.64      0.63        11
#
#
# Train_Set
# [[53  0]
#  [ 0 38]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        53
#            1       1.00      1.00      1.00        38
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91

# %%
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm

# %% [markdown]
# ![image.png](attachment:0bd7398a-b473-4f1d-a202-77f92543df85.png)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %%
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
eval_metric(classifier, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[2 3]
#  [1 5]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.62      0.83      0.71         6
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.62      0.61        11
# weighted avg       0.64      0.64      0.62        11
#
#
# Train_Set
# [[51  2]
#  [ 1 37]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        53
#            1       0.95      0.97      0.96        38
#
#     accuracy                           0.97        91
#    macro avg       0.96      0.97      0.97        91
# weighted avg       0.97      0.97      0.97        91

# %%
pol_feature = PolynomialFeatures(degree=2)
X_train = pol_feature.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (91, 378)

# %%
X_test = pol_feature.transform(X_test)

# %%
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
eval_metric(classifier, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[4 1]
#  [3 3]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.75      0.50      0.60         6
#
#     accuracy                           0.64        11
#    macro avg       0.66      0.65      0.63        11
# weighted avg       0.67      0.64      0.63        11
#
#
# Train_Set
# [[53  0]
#  [ 0 38]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        53
#            1       1.00      1.00      1.00        38
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91

# %% [markdown]
# ### TESTING NEVER SEEN CASES

# %%
dft1 = pd.read_csv('CSV/test1.csv')
dft1.shape
# Out:
# (2, 1180)

# %%
dft2 = pd.read_csv('CSV/test2.csv')
dft2.shape
# Out:
# (3, 1180)

# %%
dfT =  pd.concat([dft1,dft2], axis = 0, ignore_index= 1)

# %%
dfT.shape
# Out:
# (5, 1180)

# %%
dfT.loc[:,col_list]
# Out:
#    tumor_type  mask_voxel_count  original_shape_Elongation  \
# 0         2.0              1852                   0.841058
# 1         2.0              2018                   0.790875
# 2         0.0             14946                   0.943968
# 3         0.0              2508                   0.418093
# 4         0.0             11075                   0.971305
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.807857                       18.416304
# 1                 0.631394                       12.402502
# 2                 0.606594                       28.444634
# 3                 0.387676                       14.922288
# 4                 0.703365                       20.980132
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                       22.796490                               25.612497
# 1                       19.643050                               20.248457
# 2                       46.892398                               47.507894
# 3                       38.491676                               39.051248
# 4                       29.828236                               31.400637
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                            22.825424                              27.018512
# 1                            17.029386                              22.803509
# 2                            47.507894                              57.314920
# 3                            33.105891                              20.808652
# 4                            30.364453                              39.623226
#
#    original_shape_Maximum3DDiameter  ...  diagnostics_Mask-original_VoxelNum  \
# 0                         29.359837  ...                                1852
# 1                         23.600847  ...                                2018
# 2                         62.465991  ...                               14946
# 3                         41.484937  ...                                2508
# 4                         40.074930  ...                               11075
#
#    diagnostics_Mask-original_VolumeNum  diagnostics_Image-interpolated_Mean  \
# 0                                    1                           101.809057
# 1                                    1                            89.719355
# 2                                    1                            95.701226
# 3                                    1                            94.437928
# 4                                    1                            74.282843
#
#    diagnostics_Image-interpolated_Minimum  \
# 0                               77.656555
# 1                             -122.930227
# 2                              -32.790072
# 3                               68.787269
# 4                               54.969240
#
#    diagnostics_Image-interpolated_Maximum  \
# 0                              127.097652
# 1                              147.131874
# 2                              139.409458
# 3                              143.270837
# 4                               88.770727
#
#    diagnostics_Mask-interpolated_VoxelNum  \
# 0                                    5360
# 1                                    2475
# 2                                   38190
# 3                                    5915
# 4                                   12047
#
#    diagnostics_Mask-interpolated_VolumeNum  \
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
#
#    diagnostics_Mask-interpolated_Mean  diagnostics_Mask-interpolated_Minimum  \
# 0                          101.731244                              83.859471
# 1                           97.174165                              63.144627
# 2                           96.579823                              77.033326
# 3                           95.171674                              68.883276
# 4                           76.278088                              59.558391
#
#    diagnostics_Mask-interpolated_Maximum
# 0                             110.307011
# 1                             135.026485
# 2                             127.610730
# 3                             109.197456
# 4                              85.168948
#
# [5 rows x 1145 columns]

# %%
dfT_scaled = sc.transform(dfT.loc[:,col_list])

# %%
dfT_scaled.shape
# Out:
# (5, 1145)

# %%
scaled_df_pca.shape
# Out:
# (102, 1145)

# %%
p_dfT_scaled = pca.transform(dfT_scaled)

# %%
svc.predict(p_dfT_scaled)
# Out:
# array([0, 0, 0, 0, 0])
