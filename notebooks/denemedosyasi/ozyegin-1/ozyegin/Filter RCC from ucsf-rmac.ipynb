# %%
import os
import pandas as pd
import numpy as np

# %%
  a1 = ['xStGbIsHhB', 'oBcGJJoUuW', 'kQCfJp5tkL', 'ERd6Ak32XT', 'rjhZmlb5f3','oSYQu46cy8', 
  'tX93r2Wx5X', '475HQrHo5Y', 'ZJqn6Mcg6s', 'j2LI171wd1', 'plAj6dZmnS','bHQORJrarp', 
  'vdTLGLhQc9', 'BRvha4ynJQ', 'EyphhByKpf', 'QNDAa9SoJ7', 'UF3bv4WiV5','UAsT1Y4vFB', 
  'aX94wgAtcj', 'fvHwwVjeqZ', '5OjuFGw7YB', 'sdNEsiFv4i', 'C0nbGmupEp','x1Nq4Y0PrP', 
  'ubDnfl6DDg', '1AscaGPb3A', 'Vw4B0Hdm0V', 'Itoa3dD0xy', 'Xr9i2bphzA','5VcthT0eZp', 
  'rsDjursbKT', 'L9nWJGMxOY', '0MPL7wuVkw', 'gdvLZS8Muw', 'lkGMd9ZBs3','6RBnqjxEkG', 
  'KrODLKNxbp', 'eM3LBxKCbv', 'Wmbjh4OdZp', 'GjNVzVy1oq', 'GvrzotPyFr','yeB8XUW3cP', 
  'nPHMBD1BM4', 'zaygWiS6Rv', '9zuctMrDLy', 'B3uXUCxmk3', 'VzNDxCT8fa','5ib8uWd5du', 
  'VyIRlglwu4', 'HNch9McXGw', 'vD9qAtW7ue', '803nPFUCeM', '74WePUTw3X','JkVchHRgAl', 
  'uGjmTUbrQg', '7BLB0KcV0w', 'ubeEmmGI2q', 'xSc42srIGT', 'mCggRyNDGu','LeZNKgtSPf', 
  'U12PW8VufV', 'jiuPdpa9rh', 'N0ntKhL5k9', 'AkNLgafarf', 'aS5XqDq1sV','kEeFXbRNip', 
  'uxo0RZ6dmz', 'pWfvOWoiHg', 'O9oqCGd1m8', 'RgTSGbktCT', 'WC3J7Q0yat','pwk8XA5877', 
  'Bp45c0cJpw', '7DR2PsbosF', '4Weo6O8yjD', 'P7o3Jv8ZTo', 'fUuItGkARL','uDgXxF1ila', 
  'GUbvJyiiiM', 'PAzxVObGPj', 'nmkL2vsT7O', 'lug9RFZoKU', '5s1Tf2blEc','dYcd9yAtHc', 
  'kuLnglAoYW', '3Jq8meEZS6', 'cio6hnPCvm', 'rHrX0BpUcX', 'C5pArWvMz6','8Gj1kgX1lm', 
  'RzuLk6CZhm', 'M9LioKGbDs', 'ByY2Oz0f16', 'YmtcogTImt', 'DMay5Rd9ah','l8b3UuMplz', 
  'SJfGeC6lEo', '67dOzUc2Fv', '0cb2z7Hao2', 'djON7wYxct', 'QcyodOs3Q5','uA2OtWAm7N', 
  'LAmjEEc91Q', 'LjloyeWM1M', 'zmwtNTDvF2', 'pepayOM0wq', 'VWSZ1yg5dB','1MczhrNg62', 
  'tHI0j8MuGv', 'mpR4Lkg6WJ', 'hA43sJukAq', 'tWHXsbhqIm', 'I5vsb46qUr','yi3foephc9', 
  '4k47p1epGP', 'uMyIVuvbjp', '9b2XTJnjxM', 'KKmlJjE0CU', 'wsJhdPOISp','rRvx76VOkJ', 
  'cQRzFyfT4r', 'hFfB77MNo6', 'cPj1W4qpHw', 'R7kHGYfcbD', 'ffBxhDAVNI','wOYjdTBFCX', 
  'BO1IyjmA7c', 'sFka2A1I8Y', 'TQQhqWaFKO', 'H0SIthOhzR', 'LMe4BcXsGZ','4iE63zKDkT', 
  'fyzo1EqXd7', 'kUK49QCmgA', 'TguxBIfNqY', 'NCpS1WrC5w', 'AjyTZDJQaK','Vt6gxIpVy6', 
  'dXHjgoqnqL', 'LI7VGJbXvc', 'SEDHme2i7H', 'Kj1CwI3ZoP', 'kMi6Z72Hbu','SZzHtB9LLY', 
  'K7JmPPj855', 'NJUN3JfNRo', '1mnNua5vBc', 'YJk4NXWrV8', 'px8KYbjpUn','dTbUxojOyn', 
  'uQGlW9Azw3', 'cvtetEm3Oa', 'KZOHPiZbJJ', '3nj5dC5VxI', 'tJcQnSzMF2','QpyB9ZBOn0', 
  'xNvKCUat0i', 'q6G2RYt5pe', 'T9DYB7RAy2', 'poYCTy5BtX', 'blKfVgiI4K','khay7AoujT', 
  'v6wvKeGL12', 'iGANN43o0R', 'XMpZNkQJfr', '3LYUFVSwiY', 'V332oe0Fzg','5a1Avs4klU', 
  '33JkPNZHOn', 'RclUDEPCYc', 'Fkhkqn5dVq', 'j1raowWllH', '0uEjscJHnb','Mnx1XxZZPN', 
  'k4p2vZgzmD', 'NUnqtatiG8', 'A7SpdDCO9X', 'eCfRg9DC64', 'KEhiXKrach','h95Mq7a6E7', 
  'nDylJJeyGQ', 'aDUxKbObdS', 'XqXIZZqDfS', 'pq2ISBthWu', '99KM0R87GZ','mlDfdiP3Jx', 
  'Njt3U4nuhS', '0ByGP3oWJi', 'jsBvoI0ryF', '2p0YeE6Epp', 'SHseZLrntE','AgmMOnngBm', 
  'LI65pQmQ4Q', 'rXvFSdbJTH', 'DLLZj4NAfw', 'vuvQE5To4R', 'w9vzaZ5X9a','MWEw22Fzte', 
  'AXqILZG2b8', 'KKIh2zIhgf', 'kWVQRzWOZA', '2F2ATtAD4D', 'd7AIyXJOX0','GFYa1r7vMf', 
  'L8zvIuuyEd', 'b11klS1YRS', 'y15700W8qu', 'SBEtEbALxO', 'XwR0Gcajhw','VQZBCm863s', 
  'hWRQ8T9m0V', 'NJ4fSgWXLI', 'tsGDWuBt72', 'jdxM3Kc8ZO', 'oApAWrZ77t','HcLmTuKSvS', 
  'eb0yJkQnFy', 'NGL6ZWLsru', 'ONJbX3HplS', 'VJ789E7daS', 'i8Qcluf1mu','GajjKsrj40', 
  'Fbzmpfb4Uw', 'qTZsMCVkRC', 'B8RtzXHVC1', 'YdcAX795Jx', 'w4uUq6AnYJ','DG3cU2gBbI', 
  'QrdW2Nii6d', 'REZeFOdHho', 'gQcoKQQMTR', 'RRBLq9oDQ5', 'B311TUIPNF','zfPMdhTW2w', 
  'RYeZbvgx8V', '14GtM8ywjB', 'Ma4HafMPnr', 'WACjZxVzdQ', 'xSDslUCVg1','U3OVUsz3en', 
  'wy8JFw5trA', 'zgtiZGAduO', 'PmTcgLGmOF', '6NoqPhSMZO', '5J8adAR36L','FaYiOvtNmA', 
  'oiGJAKy6PR', 'yf6HWweKGc', 'DwCPMAGbRc', 'LePmbA07qP']

# %%
a3 = a1.copy()

# %%
a2 = ['HHpC6pFjEg','VuKea0fDmw', 'OoWZhrPYs5', 'VzMUQvofM7', 'E0WBTXpFN9', 'IjFflm1TPw', 
  'uNpFEfpq3a', '7WV4qCLwpN', 'd1EKXYcFUL', 'aiMWXsF8Vr', '7I8VYuMftc', 'mEwuO3DJRr', 
  't9JRuJ7QrH', 'urYjJBt5jE', 'uzcio3QOgb', '3aYIo3eHeN', 'xcEW63fAzX', 'W6F0t6Qf6c', 
  'OaI661IFs2', 'NAE4M7cHRj', 'dUK2PqC7E0', '5CZeU5xT7S', 'IErtSlwL1v', 'VDsRhR3sfr', 
  '7vwSJ2D2Gr', 'L6zDYFovU1', 'NCDjGn9SjQ', 'lQmquN5trS', 'AEm9rAOjhW', 'ASWZqGPpnn', 
  'gCRVTJKXKn', '6Trbnd90hn', 'AZJuZbYLEC', 'UiFv2ZcxQP', 'olBSn5qMis', 'KdrduJH9bf', 
  'NRLlNBlciW', 'bNSgKBsAWr', 'zR7ZZAwCHo', '7gqgaW1EJv', '6S3AR8Qv8n', 'bG9mfkNz4P', 
  'uGBBgG8Us6', 'XMMDMynVEF', 'sAvJP5J20M', 'vId5CDKfEG', 'ClaXJBFh2S', '9jwd7ZWijd', 
  'tP64k95G7C', 'X6B5WQvjH4', '0HW0RoqB2y', 'L7exPPUF3N', 'F0HtdH0pBx', 'DcvE7Qbk7u', 
  '9TaePY7tR2', 'HddCeQzNT4', 'qRmTxBHg0Z', 'zPnnhYGqSY', 'qaFJmu9JDn', 'kljWUCMIwZ', 
  'myAdoHhXQd', 'Iswe2OQvvA', 'AtjbHuS1d0', '3Ag6p0hB24', 'fFUuqn2Cdh', 'X910IACtaz', 
  'lFMxFYsVdR', 'fOG7qW5RFI', 'l7zTOfZuZ0', 'SkHxQ8mYSI', 'WE6o6GNpTH', 'CSgNAkMSUq', 
  'R9USCqEfWz', 'ALZseu8axq', 'FamKf6j9Ly', 'kZuoDTnHie', 'dTNNNPRqe0', 'gN54OjVPDG', 
  'QPHEXsfL0J', '58tEvb2lRX']

# %%
len(a1)
# Out:
# 250

# %%
reg = pd.read_csv('CSV/phase_reg_key.csv')

# %%
reg.tumor_type.value_counts()
# Out:
# tumor_type
# RCC               647
# oncocytoma        102
# other              42
# angiomyolipoma     30
# Name: count, dtype: int64

# %%
p = reg[reg.tumor_type == "RCC"].pid.values

# %%
len([i for i in a3 if i  in reg[reg.tumor_type == "RCC"].pid.values])
# Out:
# 250

# %%
len(a3)
# Out:
# 250

# %%
len(a1)
# Out:
# 250

# %%
len(a2)
# Out:
# 80

# %%
len(a3)
# Out:
# 250

# %%
a3.extend(a2)

# %%
len(a3)
# Out:
# 330

# %%
len(os.listdir("/media/euphrates/DS-Backup/extracted_pids"))
# Out:
# 136

# %%
sorted([i for i in a1 if i not in [i.split(".")[0] for i in os.listdir("/media/euphrates/DS-Backup/extracted_pids")]])
# Out:
# ['0ByGP3oWJi',
#  '0uEjscJHnb',
#  '14GtM8ywjB',
#  '1mnNua5vBc',
#  '2F2ATtAD4D',
#  '2p0YeE6Epp',
#  '33JkPNZHOn',
#  '3LYUFVSwiY',
#  '3nj5dC5VxI',
#  '5J8adAR36L',
#  '5a1Avs4klU',
#  '6NoqPhSMZO',
#  '99KM0R87GZ',
#  'A7SpdDCO9X',
#  'AXqILZG2b8',
#  'AgmMOnngBm',
#  'AjyTZDJQaK',
#  'B311TUIPNF',
#  'B8RtzXHVC1',
#  'DG3cU2gBbI',
#  'DLLZj4NAfw',
#  'DwCPMAGbRc',
#  'FaYiOvtNmA',
#  'Fbzmpfb4Uw',
#  'Fkhkqn5dVq',
#  'GFYa1r7vMf',
#  'GajjKsrj40',
#  'HcLmTuKSvS',
#  'K7JmPPj855',
#  'KEhiXKrach',
#  'KKIh2zIhgf',
#  'KZOHPiZbJJ',
#  'Kj1CwI3ZoP',
#  'L8zvIuuyEd',
#  'LI65pQmQ4Q',
#  'LI7VGJbXvc',
#  'LePmbA07qP',
#  'MWEw22Fzte',
#  'Ma4HafMPnr',
#  'Mnx1XxZZPN',
#  'NGL6ZWLsru',
#  'NJ4fSgWXLI',
#  'NJUN3JfNRo',
#  'NUnqtatiG8',
#  'Njt3U4nuhS',
#  'ONJbX3HplS',
#  'PmTcgLGmOF',
#  'QpyB9ZBOn0',
#  'QrdW2Nii6d',
#  'REZeFOdHho',
#  'RRBLq9oDQ5',
#  'RYeZbvgx8V',
#  'RclUDEPCYc',
#  'SBEtEbALxO',
#  'SEDHme2i7H',
#  'SHseZLrntE',
#  'SZzHtB9LLY',
#  'T9DYB7RAy2',
# ...

# %%
len(a1)
# Out:
# 250

# %%
os.listdir("/media/euphrates/DS-Backup/extracted_pids")[0].split(".")[0]
# Out:
# 'xStGbIsHhB'

# %%
[i.split(".")[0] for i in os.listdir("/media/euphrates/DS-Backup/extracted_pids")]
# Out:
# ['xStGbIsHhB',
#  'oBcGJJoUuW',
#  'kQCfJp5tkL',
#  'ERd6Ak32XT',
#  'rjhZmlb5f3',
#  'oSYQu46cy8',
#  'tX93r2Wx5X',
#  '475HQrHo5Y',
#  'ZJqn6Mcg6s',
#  'j2LI171wd1',
#  'plAj6dZmnS',
#  'bHQORJrarp',
#  'vdTLGLhQc9',
#  'BRvha4ynJQ',
#  'EyphhByKpf',
#  'QNDAa9SoJ7',
#  'UF3bv4WiV5',
#  'UAsT1Y4vFB',
#  'aX94wgAtcj',
#  'fvHwwVjeqZ',
#  '5OjuFGw7YB',
#  'sdNEsiFv4i',
#  'C0nbGmupEp',
#  'x1Nq4Y0PrP',
#  'ubDnfl6DDg',
#  '1AscaGPb3A',
#  'Vw4B0Hdm0V',
#  'Itoa3dD0xy',
#  'Xr9i2bphzA',
#  '5VcthT0eZp',
#  'rsDjursbKT',
#  'L9nWJGMxOY',
#  '0MPL7wuVkw',
#  'gdvLZS8Muw',
#  'lkGMd9ZBs3',
#  '6RBnqjxEkG',
#  'KrODLKNxbp',
#  'eM3LBxKCbv',
#  'Wmbjh4OdZp',
#  'GjNVzVy1oq',
#  'GvrzotPyFr',
#  'yeB8XUW3cP',
#  'nPHMBD1BM4',
#  'zaygWiS6Rv',
#  '9zuctMrDLy',
#  'B3uXUCxmk3',
#  'VzNDxCT8fa',
#  '5ib8uWd5du',
#  'VyIRlglwu4',
#  'HNch9McXGw',
#  'vD9qAtW7ue',
#  '803nPFUCeM',
#  '74WePUTw3X',
#  'JkVchHRgAl',
#  'uGjmTUbrQg',
#  '7BLB0KcV0w',
#  'ubeEmmGI2q',
#  'xSc42srIGT',
# ...

# %%
b = ['3aYIo3eHeN.hdf5', '6Trbnd90hn.hdf5', '7gqgaW1EJv.hdf5', '7vwSJ2D2Gr.hdf5',
    '9TaePY7tR2.hdf5', '9jwd7ZWijd.hdf5', 'ASWZqGPpnn.hdf5', 'AZJuZbYLEC.hdf5',
    'AtjbHuS1d0.hdf5', 'ClaXJBFh2S.hdf5', 'HHpC6pFjEg.hdf5', 'HddCeQzNT4.hdf5',
    'IErtSlwL1v.hdf5', 'L6zDYFovU1.hdf5', 'NAE4M7cHRj.hdf5', 'NCDjGn9SjQ.hdf5',
    'OaI661IFs2.hdf5', 'UiFv2ZcxQP.hdf5', 'VDsRhR3sfr.hdf5', 'VzMUQvofM7.hdf5',
    'WE6o6GNpTH.hdf5', 'd1EKXYcFUL.hdf5', 'dTNNNPRqe0.hdf5', 'fOG7qW5RFI.hdf5',
    'gCRVTJKXKn.hdf5', 'kZuoDTnHie.hdf5', 'l7zTOfZuZ0.hdf5', 'lFMxFYsVdR.hdf5',
    'lQmquN5trS.hdf5', 'mEwuO3DJRr.hdf5', 'myAdoHhXQd.hdf5', 'olBSn5qMis.hdf5',
    'qRmTxBHg0Z.hdf5', 'sAvJP5J20M.hdf5', 't9JRuJ7QrH.hdf5', 'tP64k95G7C.hdf5',
    'uNpFEfpq3a.hdf5', 'urYjJBt5jE.hdf5', 'uzcio3QOgb.hdf5', 'vId5CDKfEG.hdf5',
    'xcEW63fAzX.hdf5', 'zPnnhYGqSY.hdf5', 'zR7ZZAwCHo.hdf5', '0HW0RoqB2y.hdf5',
    'AEm9rAOjhW.hdf5', 'F0HtdH0pBx.hdf5', 'KdrduJH9bf.hdf5', 'NRLlNBlciW.hdf5',
    'R9USCqEfWz.hdf5', 'VuKea0fDmw.hdf5', 'W6F0t6Qf6c.hdf5', 'bG9mfkNz4P.hdf5',
    'bNSgKBsAWr.hdf5', 'dUK2PqC7E0.hdf5', 'kljWUCMIwZ.hdf5', 'uGBBgG8Us6.hdf5']

# %%
len(b)
# Out:
# 56

# %%
[i for i in [i.split(".")[0] for i in b] if i in a2]
# Out:
# ['3aYIo3eHeN',
#  '6Trbnd90hn',
#  '7gqgaW1EJv',
#  '7vwSJ2D2Gr',
#  '9TaePY7tR2',
#  '9jwd7ZWijd',
#  'ASWZqGPpnn',
#  'AZJuZbYLEC',
#  'AtjbHuS1d0',
#  'ClaXJBFh2S',
#  'HHpC6pFjEg',
#  'HddCeQzNT4',
#  'IErtSlwL1v',
#  'L6zDYFovU1',
#  'NAE4M7cHRj',
#  'NCDjGn9SjQ',
#  'OaI661IFs2',
#  'UiFv2ZcxQP',
#  'VDsRhR3sfr',
#  'VzMUQvofM7',
#  'WE6o6GNpTH',
#  'd1EKXYcFUL',
#  'dTNNNPRqe0',
#  'fOG7qW5RFI',
#  'gCRVTJKXKn',
#  'kZuoDTnHie',
#  'l7zTOfZuZ0',
#  'lFMxFYsVdR',
#  'lQmquN5trS',
#  'mEwuO3DJRr',
#  'myAdoHhXQd',
#  'olBSn5qMis',
#  'qRmTxBHg0Z',
#  'sAvJP5J20M',
#  't9JRuJ7QrH',
#  'tP64k95G7C',
#  'uNpFEfpq3a',
#  'urYjJBt5jE',
#  'uzcio3QOgb',
#  'vId5CDKfEG',
#  'xcEW63fAzX',
#  'zPnnhYGqSY',
#  'zR7ZZAwCHo',
#  '0HW0RoqB2y',
#  'AEm9rAOjhW',
#  'F0HtdH0pBx',
#  'KdrduJH9bf',
#  'NRLlNBlciW',
#  'R9USCqEfWz',
#  'VuKea0fDmw',
#  'W6F0t6Qf6c',
#  'bG9mfkNz4P',
#  'bNSgKBsAWr',
#  'dUK2PqC7E0',
#  'kljWUCMIwZ',
#  'uGBBgG8Us6']

# %%
[i.split(".")[0] for i in b]
# Out:
# ['3aYIo3eHeN',
#  '6Trbnd90hn',
#  '7gqgaW1EJv',
#  '7vwSJ2D2Gr',
#  '9TaePY7tR2',
#  '9jwd7ZWijd',
#  'ASWZqGPpnn',
#  'AZJuZbYLEC',
#  'AtjbHuS1d0',
#  'ClaXJBFh2S',
#  'HHpC6pFjEg',
#  'HddCeQzNT4',
#  'IErtSlwL1v',
#  'L6zDYFovU1',
#  'NAE4M7cHRj',
#  'NCDjGn9SjQ',
#  'OaI661IFs2',
#  'UiFv2ZcxQP',
#  'VDsRhR3sfr',
#  'VzMUQvofM7',
#  'WE6o6GNpTH',
#  'd1EKXYcFUL',
#  'dTNNNPRqe0',
#  'fOG7qW5RFI',
#  'gCRVTJKXKn',
#  'kZuoDTnHie',
#  'l7zTOfZuZ0',
#  'lFMxFYsVdR',
#  'lQmquN5trS',
#  'mEwuO3DJRr',
#  'myAdoHhXQd',
#  'olBSn5qMis',
#  'qRmTxBHg0Z',
#  'sAvJP5J20M',
#  't9JRuJ7QrH',
#  'tP64k95G7C',
#  'uNpFEfpq3a',
#  'urYjJBt5jE',
#  'uzcio3QOgb',
#  'vId5CDKfEG',
#  'xcEW63fAzX',
#  'zPnnhYGqSY',
#  'zR7ZZAwCHo',
#  '0HW0RoqB2y',
#  'AEm9rAOjhW',
#  'F0HtdH0pBx',
#  'KdrduJH9bf',
#  'NRLlNBlciW',
#  'R9USCqEfWz',
#  'VuKea0fDmw',
#  'W6F0t6Qf6c',
#  'bG9mfkNz4P',
#  'bNSgKBsAWr',
#  'dUK2PqC7E0',
#  'kljWUCMIwZ',
#  'uGBBgG8Us6']

# %%
c = ['XMMDMynVEF.hdf5',
 'gN54OjVPDG.hdf5',
 'IjFflm1TPw.hdf5',
 '58tEvb2lRX.hdf5',
 'FamKf6j9Ly.hdf5',
 '7WV4qCLwpN.hdf5',
 '5CZeU5xT7S.hdf5',
 'E0WBTXpFN9.hdf5',
 'CSgNAkMSUq.hdf5',
 'DcvE7Qbk7u.hdf5',
 'L7exPPUF3N.hdf5',
 'X910IACtaz.hdf5',
 '3Ag6p0hB24.hdf5',
 'SkHxQ8mYSI.hdf5',
 '7I8VYuMftc.hdf5',
 'Iswe2OQvvA.hdf5',
 'fFUuqn2Cdh.hdf5',
 'X6B5WQvjH4.hdf5',
 'ALZseu8axq.hdf5',
 '6S3AR8Qv8n.hdf5',
 'aiMWXsF8Vr.hdf5',
 'QPHEXsfL0J.hdf5',
 'qaFJmu9JDn.hdf5',
 'OoWZhrPYs5.hdf5','pepayOM0wq.hdf5',
 'rjhZmlb5f3.hdf5',
 'LAmjEEc91Q.hdf5',
 'Wmbjh4OdZp.hdf5',
 '67dOzUc2Fv.hdf5',
 'L9nWJGMxOY.hdf5',
 'mCggRyNDGu.hdf5',
 '6RBnqjxEkG.hdf5',
 'Vw4B0Hdm0V.hdf5',
 'EyphhByKpf.hdf5',
 '5s1Tf2blEc.hdf5',
 'pWfvOWoiHg.hdf5',
 '0MPL7wuVkw.hdf5',
 'cio6hnPCvm.hdf5',
 'uxo0RZ6dmz.hdf5',
 'C0nbGmupEp.hdf5',
 'KrODLKNxbp.hdf5',
 'Xr9i2bphzA.hdf5',
 'djON7wYxct.hdf5',
 'xStGbIsHhB.hdf5',
 'O9oqCGd1m8.hdf5',
 'B3uXUCxmk3.hdf5',
 '1AscaGPb3A.hdf5',
 'dYcd9yAtHc.hdf5',
 'LjloyeWM1M.hdf5',
 'UF3bv4WiV5.hdf5',
 'j2LI171wd1.hdf5',
 'M9LioKGbDs.hdf5',
 'pwk8XA5877.hdf5',
 'QcyodOs3Q5.hdf5',
 'kQCfJp5tkL.hdf5',
 'tHI0j8MuGv.hdf5',
 'YmtcogTImt.hdf5',
 '5VcthT0eZp.hdf5',
 'HNch9McXGw.hdf5',
 '0cb2z7Hao2.hdf5',
 'uDgXxF1ila.hdf5',
 'ZJqn6Mcg6s.hdf5',
 'lkGMd9ZBs3.hdf5',
 '475HQrHo5Y.hdf5',
 'UAsT1Y4vFB.hdf5',
 'zmwtNTDvF2.hdf5',
 '7DR2PsbosF.hdf5',
 'kuLnglAoYW.hdf5',
 'WC3J7Q0yat.hdf5',
 'fvHwwVjeqZ.hdf5',
 '1MczhrNg62.hdf5',
 'RzuLk6CZhm.hdf5',
 'VyIRlglwu4.hdf5',
 'VWSZ1yg5dB.hdf5',
 'tWHXsbhqIm.hdf5',
 'mpR4Lkg6WJ.hdf5',
 '9zuctMrDLy.hdf5',
 'AkNLgafarf.hdf5',
 'rsDjursbKT.hdf5',
 'JkVchHRgAl.hdf5',
 'U12PW8VufV.hdf5',
 'bHQORJrarp.hdf5',
 '74WePUTw3X.hdf5',
 'ByY2Oz0f16.hdf5',
 'QNDAa9SoJ7.hdf5',
 'tX93r2Wx5X.hdf5',
 'C5pArWvMz6.hdf5',
 '8Gj1kgX1lm.hdf5',
 'VzNDxCT8fa.hdf5',
 'nmkL2vsT7O.hdf5',
 'lug9RFZoKU.hdf5',
 'oBcGJJoUuW.hdf5',
 '5ib8uWd5du.hdf5',
 'I5vsb46qUr.hdf5',
 'kEeFXbRNip.hdf5',
 'Bp45c0cJpw.hdf5',
 '803nPFUCeM.hdf5',
 'vdTLGLhQc9.hdf5',
 '7BLB0KcV0w.hdf5',
 'GUbvJyiiiM.hdf5',
 'SJfGeC6lEo.hdf5',
 'aX94wgAtcj.hdf5',
 'gdvLZS8Muw.hdf5',
 'oSYQu46cy8.hdf5',
 'GvrzotPyFr.hdf5',
 'jiuPdpa9rh.hdf5',
 'Itoa3dD0xy.hdf5',
 '5OjuFGw7YB.hdf5',
 'nPHMBD1BM4.hdf5',
 'yi3foephc9.hdf5',
 'RgTSGbktCT.hdf5',
 '4Weo6O8yjD.hdf5',
 'sdNEsiFv4i.hdf5',
 '3Jq8meEZS6.hdf5',
 'P7o3Jv8ZTo.hdf5',
 'fUuItGkARL.hdf5',
 'aS5XqDq1sV.hdf5',
 'x1Nq4Y0PrP.hdf5',
 'rHrX0BpUcX.hdf5',
 'uA2OtWAm7N.hdf5',
 'xSc42srIGT.hdf5',
 'plAj6dZmnS.hdf5',
 'ubDnfl6DDg.hdf5',
 'l8b3UuMplz.hdf5',
 'hA43sJukAq.hdf5',
 'DMay5Rd9ah.hdf5',
 'N0ntKhL5k9.hdf5',
 'LeZNKgtSPf.hdf5',
 'ubeEmmGI2q.hdf5',
 'GjNVzVy1oq.hdf5',
 'ERd6Ak32XT.hdf5',
 'uGjmTUbrQg.hdf5',
 'zaygWiS6Rv.hdf5',
 'BRvha4ynJQ.hdf5',
 'eM3LBxKCbv.hdf5',
 'PAzxVObGPj.hdf5',
 'yeB8XUW3cP.hdf5',
  'vD9qAtW7ue.hdf5']

# %%
len(c)
# Out:
# 138

# %%
[i for i in p if i not in [i.split(".")[0] for i in c]]
# Out:
# ['0ByGP3oWJi',
#  '0HW0RoqB2y',
#  '0pNwg9v73Z',
#  '0qtu3yMgoH',
#  '0rXGJnmwRI',
#  '0uEjscJHnb',
#  '13Dvlj0sae',
#  '14GtM8ywjB',
#  '1DAAjZKcBn',
#  '1Ib0h6lHic',
#  '1T38wBR6vx',
#  '1mnNua5vBc',
#  '1sb6GNzkwo',
#  '2F2ATtAD4D',
#  '2LjRhxuAKk',
#  '2p0YeE6Epp',
#  '2pAVprZ7PU',
#  '320QmLytoR',
#  '33JkPNZHOn',
#  '3IXdHy60WM',
#  '3LYUFVSwiY',
#  '3aLkePWRfq',
#  '3aYIo3eHeN',
#  '3nj5dC5VxI',
#  '3q1CPr0HcQ',
#  '4bTUoSzILp',
#  '4g2jJP2syO',
#  '4iE63zKDkT',
#  '4k47p1epGP',
#  '4vAkE0SXvh',
#  '4ycNInAFKz',
#  '53bZsQpbUX',
#  '58EHoFml4k',
#  '5EO3ZwmwI4',
#  '5J8adAR36L',
#  '5N7lkJ0kDs',
#  '5UYwSLaGJ6',
#  '5ZBLcJRo6p',
#  '5a1Avs4klU',
#  '5iVqGc7MCW',
#  '5m4h4XTnxI',
#  '5vUM50Qb0y',
#  '6BGlCnxaol',
#  '6NoqPhSMZO',
#  '6RG177cQ1W',
#  '6Trbnd90hn',
#  '6X72bRxwln',
#  '6msZHHm8qR',
#  '72UWEZcv7D',
#  '78CsnJ4RVm',
#  '7NlB4LmwWM',
#  '7gqgaW1EJv',
#  '7nnOxttVYV',
#  '7vwSJ2D2Gr',
#  '7wWLGsiV5I',
#  '8IAFkRyNZq',
#  '8R4lqpjAF2',
#  '8l3GaP37d0',
# ...

# %%
len([i for i in p if i not in [i.split(".")[0] for i in c]])
# Out:
# 509

# %%
647-138
# Out:
# 509

# %%
import random, math

# %%
random.sample([i for i in p if i not in [i.split(".")[0] for i in c]],109)
# Out:
# ['4vAkE0SXvh',
#  'oVdadphEmf',
#  'LI65pQmQ4Q',
#  'xcEW63fAzX',
#  'UDBvBoHG3i',
#  'wtyhlabvPF',
#  'VY6YkrXqwH',
#  'aDUxKbObdS',
#  'qRmTxBHg0Z',
#  '99KM0R87GZ',
#  'AEm9rAOjhW',
#  'T9DYB7RAy2',
#  'poYCTy5BtX',
#  'RclUDEPCYc',
#  'Rl9yzeZJSt',
#  'CPYZ4YesLX',
#  '6msZHHm8qR',
#  'gYlaPfQdtZ',
#  'ODDsYSYna9',
#  'FHUBnRWXRF',
#  'PmTcgLGmOF',
#  'ToyVAxDQIa',
#  'r0qjGxLSUw',
#  '4iE63zKDkT',
#  'ONJbX3HplS',
#  'ffBxhDAVNI',
#  'niyL112s59',
#  'L6zDYFovU1',
#  'QbyUKBeqIM',
#  'e25VAq7MKH',
#  'rdKMacoScX',
#  'KpzrWMD5Im',
#  'SHseZLrntE',
#  'hHIrJAxWST',
#  'uNpFEfpq3a',
#  '72UWEZcv7D',
#  'ZCCGfiyV9c',
#  'VOkYFOdnat',
#  'VCUnp7gYWl',
#  'jTJuf0WsAc',
#  'khtNyB6FTN',
#  'cQRzFyfT4r',
#  'HOu6uNXQoc',
#  '2LjRhxuAKk',
#  'cPj1W4qpHw',
#  'LghoUu1teF',
#  '6BGlCnxaol',
#  'yAKBRm37rl',
#  'tu639KniLm',
#  'GwH7ivIt8w',
#  'WfqIfiJmua',
#  'eVOx8jYK9h',
#  'gQcoKQQMTR',
#  '5N7lkJ0kDs',
#  '7gqgaW1EJv',
#  'kgd3N6kGy1',
#  'vId5CDKfEG',
#  'glIsMfn6i4',
# ...

# %%
math.random([i for i in p if i not in [i.split(".")[0] for i in c]],109)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 math.random([i for i in p if i not in [i.split(".")[0] for i in c]],109)
#
# AttributeError: module 'math' has no attribute 'random'

# %%
#In Google Drive

# %%
ls = []

# %%
extracted_pid1 = ['XMMDMynVEF.hdf5',
 'gN54OjVPDG.hdf5',
 'IjFflm1TPw.hdf5',
 '58tEvb2lRX.hdf5',
 'FamKf6j9Ly.hdf5',
 '7WV4qCLwpN.hdf5',
 '5CZeU5xT7S.hdf5',
 'E0WBTXpFN9.hdf5',
 'CSgNAkMSUq.hdf5',
 'DcvE7Qbk7u.hdf5',
 'L7exPPUF3N.hdf5',
 'X910IACtaz.hdf5',
 '3Ag6p0hB24.hdf5',
 'SkHxQ8mYSI.hdf5',
 '7I8VYuMftc.hdf5',
 'Iswe2OQvvA.hdf5',
 'fFUuqn2Cdh.hdf5',
 'X6B5WQvjH4.hdf5',
 'ALZseu8axq.hdf5',
 '6S3AR8Qv8n.hdf5',
 'aiMWXsF8Vr.hdf5',
 'QPHEXsfL0J.hdf5',
 'qaFJmu9JDn.hdf5',
 'OoWZhrPYs5.hdf5']

# %%
extracted_pid2 = ['pepayOM0wq.hdf5',
 'rjhZmlb5f3.hdf5',
 'LAmjEEc91Q.hdf5',
 'Wmbjh4OdZp.hdf5',
 '67dOzUc2Fv.hdf5',
 'L9nWJGMxOY.hdf5',
 'mCggRyNDGu.hdf5',
 '6RBnqjxEkG.hdf5',
 'Vw4B0Hdm0V.hdf5',
 'EyphhByKpf.hdf5',
 '5s1Tf2blEc.hdf5',
 'pWfvOWoiHg.hdf5',
 '0MPL7wuVkw.hdf5',
 'cio6hnPCvm.hdf5',
 'uxo0RZ6dmz.hdf5',
 'C0nbGmupEp.hdf5',
 'KrODLKNxbp.hdf5',
 'Xr9i2bphzA.hdf5',
 'djON7wYxct.hdf5',
 'xStGbIsHhB.hdf5',
 'O9oqCGd1m8.hdf5',
 'B3uXUCxmk3.hdf5',
 '1AscaGPb3A.hdf5',
 'dYcd9yAtHc.hdf5',
 'LjloyeWM1M.hdf5',
 'UF3bv4WiV5.hdf5',
 'j2LI171wd1.hdf5',
 'M9LioKGbDs.hdf5',
 'pwk8XA5877.hdf5',
 'QcyodOs3Q5.hdf5',
 'kQCfJp5tkL.hdf5',
 'tHI0j8MuGv.hdf5',
 'YmtcogTImt.hdf5',
 '5VcthT0eZp.hdf5',
 'HNch9McXGw.hdf5',
 '0cb2z7Hao2.hdf5',
 'uDgXxF1ila.hdf5',
 'ZJqn6Mcg6s.hdf5',
 'lkGMd9ZBs3.hdf5',
 '475HQrHo5Y.hdf5',
 'UAsT1Y4vFB.hdf5',
 'zmwtNTDvF2.hdf5',
 '7DR2PsbosF.hdf5',
 'kuLnglAoYW.hdf5',
 'WC3J7Q0yat.hdf5',
 'fvHwwVjeqZ.hdf5',
 '1MczhrNg62.hdf5',
 'RzuLk6CZhm.hdf5',
 'VyIRlglwu4.hdf5',
 'VWSZ1yg5dB.hdf5',
 'tWHXsbhqIm.hdf5',
 'mpR4Lkg6WJ.hdf5',
 '9zuctMrDLy.hdf5',
 'AkNLgafarf.hdf5',
 'rsDjursbKT.hdf5',
 'JkVchHRgAl.hdf5',
 'U12PW8VufV.hdf5',
 'bHQORJrarp.hdf5',
 '74WePUTw3X.hdf5',
 'ByY2Oz0f16.hdf5',
 'QNDAa9SoJ7.hdf5',
 'tX93r2Wx5X.hdf5',
 'C5pArWvMz6.hdf5',
 '8Gj1kgX1lm.hdf5',
 'VzNDxCT8fa.hdf5',
 'nmkL2vsT7O.hdf5',
 'lug9RFZoKU.hdf5',
 'oBcGJJoUuW.hdf5',
 '5ib8uWd5du.hdf5',
 'I5vsb46qUr.hdf5',
 'kEeFXbRNip.hdf5',
 'Bp45c0cJpw.hdf5',
 '803nPFUCeM.hdf5',
 'vdTLGLhQc9.hdf5',
 '7BLB0KcV0w.hdf5',
 'GUbvJyiiiM.hdf5',
 'SJfGeC6lEo.hdf5',
 'aX94wgAtcj.hdf5',
 'gdvLZS8Muw.hdf5',
 'oSYQu46cy8.hdf5',
 'GvrzotPyFr.hdf5',
 'jiuPdpa9rh.hdf5',
 'Itoa3dD0xy.hdf5',
 '5OjuFGw7YB.hdf5',
 'nPHMBD1BM4.hdf5',
 'yi3foephc9.hdf5',
 'RgTSGbktCT.hdf5',
 '4Weo6O8yjD.hdf5',
 'sdNEsiFv4i.hdf5',
 '3Jq8meEZS6.hdf5',
 'P7o3Jv8ZTo.hdf5',
 'fUuItGkARL.hdf5',
 'aS5XqDq1sV.hdf5',
 'x1Nq4Y0PrP.hdf5',
 'rHrX0BpUcX.hdf5',
 'uA2OtWAm7N.hdf5',
 'xSc42srIGT.hdf5',
 'plAj6dZmnS.hdf5',
 'ubDnfl6DDg.hdf5',
 'l8b3UuMplz.hdf5',
 'hA43sJukAq.hdf5',
 'DMay5Rd9ah.hdf5',
 'N0ntKhL5k9.hdf5',
 'LeZNKgtSPf.hdf5',
 'ubeEmmGI2q.hdf5',
 'GjNVzVy1oq.hdf5',
 'ERd6Ak32XT.hdf5',
 'uGjmTUbrQg.hdf5',
 'zaygWiS6Rv.hdf5',
 'BRvha4ynJQ.hdf5',
 'eM3LBxKCbv.hdf5',
 'PAzxVObGPj.hdf5',
 'yeB8XUW3cP.hdf5',
 'vD9qAtW7ue.hdf5']

# %%
extracted_pid3 = ['4vAkE0SXvh',
 'oVdadphEmf',
 'LI65pQmQ4Q',
 'xcEW63fAzX',
 'UDBvBoHG3i',
 'wtyhlabvPF',
 'VY6YkrXqwH',
 'aDUxKbObdS',
 'qRmTxBHg0Z',
 '99KM0R87GZ',
 'AEm9rAOjhW',
 'T9DYB7RAy2',
 'poYCTy5BtX',
 'RclUDEPCYc',
 'Rl9yzeZJSt',
 'CPYZ4YesLX',
 '6msZHHm8qR',
 'gYlaPfQdtZ',
 'ODDsYSYna9',
 'FHUBnRWXRF',
 'PmTcgLGmOF',
 'ToyVAxDQIa',
 'r0qjGxLSUw',
 '4iE63zKDkT',
 'ONJbX3HplS',
 'ffBxhDAVNI',
 'niyL112s59',
 'L6zDYFovU1',
 'QbyUKBeqIM',
 'e25VAq7MKH',
 'rdKMacoScX',
 'KpzrWMD5Im',
 'SHseZLrntE',
 'hHIrJAxWST',
 'uNpFEfpq3a',
 '72UWEZcv7D',
 'ZCCGfiyV9c',
 'VOkYFOdnat',
 'VCUnp7gYWl',
 'jTJuf0WsAc',
 'khtNyB6FTN',
 'cQRzFyfT4r',
 'HOu6uNXQoc',
 '2LjRhxuAKk',
 'cPj1W4qpHw',
 'LghoUu1teF',
 '6BGlCnxaol',
 'yAKBRm37rl',
 'tu639KniLm',
 'GwH7ivIt8w',
 'WfqIfiJmua',
 'eVOx8jYK9h',
 'gQcoKQQMTR',
 '5N7lkJ0kDs',
 '7gqgaW1EJv',
 'kgd3N6kGy1',
 'vId5CDKfEG',
 'glIsMfn6i4',
 'FaYiOvtNmA',
 'sAvJP5J20M',
 'p68oQ3OJH2',
 'KEhiXKrach',
 'QpyB9ZBOn0',
 'lYVNJKo2KA',
 'zc6BH8zA6L',
 'w0ZLcnroNW',
 'HcLmTuKSvS',
 'Vt6gxIpVy6',
 '9jwd7ZWijd',
 'BO1IyjmA7c',
 'mz52rQBYK4',
 'SBEtEbALxO',
 '1mnNua5vBc',
 'gGgBAhhswV',
 '5UYwSLaGJ6',
 'wkk3nhrcl5',
 'LI7VGJbXvc',
 'FuGBYPuG3b',
 'SjOsLR7r8e',
 'lQmquN5trS',
 'qbY9mCcXNe',
 'uFL9tjKsAg',
 'RRBLq9oDQ5',
 'BtFicKWjri',
 '9pV043YPNV',
 'y15700W8qu',
 'nZzrR0U5BX',
 'tP64k95G7C',
 'vuvQE5To4R',
 'RgkUukyoLP',
 'HHBuhqb5k8',
 '3nj5dC5VxI',
 'nh1sRqpU6L',
 'lkHI3FuIT0',
 'B311TUIPNF',
 'VzMUQvofM7',
 '7NlB4LmwWM',
 'I2rhATl4KH',
 'AO8CYyeCa5',
 '4k47p1epGP',
 'n5GsTkRyd1',
 '1T38wBR6vx',
 'HHpC6pFjEg',
 'oApAWrZ77t',
 '8R4lqpjAF2',
 'd1EKXYcFUL',
 'fe1SgE9ikt',
 'uMyIVuvbjp',
 'ms3C7rDYuO']

# %%
#ls.extend(extracted_pid3)

# %%
ls  #toplam google drive daki RCC hdf5 ler

# %%
len(extracted_pid1),len(extracted_pid2),len(extracted_pid3)
# Out:
# (24, 114, 109)

# %%
len(ls)
# Out:
# 247
